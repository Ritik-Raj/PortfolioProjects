# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd  #importing pandas

# %% [markdown]
# ## Importing the dataset

# %%
data= pd.read_excel(r"E:\Priority\Data Analytics\Project Portfolio\Python\project2\project tasks_data_mito.xlsx")  #importing excel file

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15
# ...

# %% [markdown]
# ## Checking Shape of data

# %%
data.shape
# Out:
# (51263, 16)

# %% [markdown]
# ## Adding a new column

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15
# ...

# %%
data["new_quantity"]= data["quantity"]*10

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %% [markdown]
# ## Adding a new column at a particular place

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %%
data.insert(10, "new_sales" , data.sales*100)

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales new_sales quantity  discount   profit    year  Unnamed: 14  \
# ...

# %% [markdown]
# ## Delete a column

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales new_sales quantity  discount   profit    year  Unnamed: 14  \
# ...

# %%
data.drop("customer_name", axis=1)  #axis1 for column, axis0 for rows
# Out:
#               order_id  order_date      segment        country   region  \
# 0         AG-2011-2040       40544     Consumer        Algeria   Africa
# 1        IN-2011-47883       40544     Consumer      Australia  Oceania
# 2         HU-2011-1220       40544     Consumer        Hungary     EMEA
# 3      IT-2011-3647632       40544  Home Office         Sweden    North
# 4        IN-2011-47883       40544     Consumer      Australia  Oceania
# ...                ...         ...          ...            ...      ...
# 51258   CA-2014-115427       42004    Corporate  United States     West
# 51259     MO-2014-2560       42004     Consumer        Morocco   Africa
# 51260   MX-2014-110527       42004     Consumer      Nicaragua  Central
# 51261   MX-2014-114783       42004     Consumer         Mexico    North
# 51262   CA-2014-156720       42004     Consumer  United States     West
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# ...

# %%
data.head()  #but it is still here in the original data
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040       40544  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220       40544    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632       40544     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883       40544      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales new_sales quantity  discount   profit    year  Unnamed: 14  \
# ...

# %%
data.drop("customer_name", axis=1, inplace=True)  #for deleting permanently use inplace

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040       40544     Consumer    Algeria   Africa
# 1    IN-2011-47883       40544     Consumer  Australia  Oceania
# 2     HU-2011-1220       40544     Consumer    Hungary     EMEA
# 3  IT-2011-3647632       40544  Home Office     Sweden    North
# 4    IN-2011-47883       40544     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#   new_sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %% [markdown]
# ## Sorting a dataframe

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040       40544     Consumer    Algeria   Africa
# 1    IN-2011-47883       40544     Consumer  Australia  Oceania
# 2     HU-2011-1220       40544     Consumer    Hungary     EMEA
# 3  IT-2011-3647632       40544  Home Office     Sweden    North
# 4    IN-2011-47883       40544     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#   new_sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %%
data.sort_values(by="profit")  #by default in ascending
# Out:
#              order_id  order_date      segment        country   region  \
# 31868  CA-2013-108196       41604     Consumer  United States     East
# 29196    TU-2013-9400       41543    Corporate         Turkey     EMEA
# 47171  US-2014-168116       41948    Corporate  United States    South
# 3771   CA-2011-169019       40750     Consumer  United States  Central
# 37111  CA-2014-134845       41747  Home Office  United States     West
# ...               ...         ...          ...            ...      ...
# 5517   CA-2011-116904       40809     Consumer  United States  Central
# 32993  CA-2013-117121       41626     Consumer  United States  Central
# 48072  CA-2014-166709       41961     Consumer  United States     East
# 36220  CA-2014-140151       41722     Consumer  United States     West
# 29514  CA-2013-118689       41550    Corporate  United States  Central
#
#              product_id         category  \
# 31868   TEC-MA-10000418       Technology
# ...

# %%
data.sort_values(by="profit", ascending=False)  #for getting sorted in descending
# Out:
#              order_id  order_date      segment        country   region  \
# 29514  CA-2013-118689       41550    Corporate  United States  Central
# 36220  CA-2014-140151       41722     Consumer  United States     West
# 48072  CA-2014-166709       41961     Consumer  United States     East
# 32993  CA-2013-117121       41626     Consumer  United States  Central
# 5517   CA-2011-116904       40809     Consumer  United States  Central
# ...               ...         ...          ...            ...      ...
# 37111  CA-2014-134845       41747  Home Office  United States     West
# 3771   CA-2011-169019       40750     Consumer  United States  Central
# 47171  US-2014-168116       41948    Corporate  United States    South
# 29196    TU-2013-9400       41543    Corporate         Turkey     EMEA
# 31868  CA-2013-108196       41604     Consumer  United States     East
#
#              product_id         category  \
# 29514   TEC-CO-10004722       Technology
# ...

# %% [markdown]
# ## Filter dataset (single column/condition)

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040       40544     Consumer    Algeria   Africa
# 1    IN-2011-47883       40544     Consumer  Australia  Oceania
# 2     HU-2011-1220       40544     Consumer    Hungary     EMEA
# 3  IT-2011-3647632       40544  Home Office     Sweden    North
# 4    IN-2011-47883       40544     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#   new_sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %%
data[data["region"]== "Africa"]  #applying filter with single condition
# Out:
#            order_id  order_date      segment      country  region  \
# 0      AG-2011-2040       40544     Consumer      Algeria  Africa
# 23     TZ-2011-7370       40546     Consumer     Tanzania  Africa
# 41     SU-2011-5190       40547     Consumer        Sudan  Africa
# 42     SU-2011-5190       40547     Consumer        Sudan  Africa
# 55     AO-2011-4910       40549    Corporate       Angola  Africa
# ...             ...         ...          ...          ...     ...
# 51225  OD-2014-9490       42004    Corporate  South Sudan  Africa
# 51226  AO-2014-7730       42004     Consumer       Angola  Africa
# 51235  TZ-2014-8350       42004     Consumer     Tanzania  Africa
# 51253  TZ-2014-8220       42004  Home Office     Tanzania  Africa
# 51259  MO-2014-2560       42004     Consumer      Morocco  Africa
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# 23     OFF-STI-10000388  Office Supplies
# 41     OFF-BOS-10004950  Office Supplies
# ...

# %% [markdown]
# ## Filter dataframe (multiple columns/conditions)-AND operator

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040       40544     Consumer    Algeria   Africa
# 1    IN-2011-47883       40544     Consumer  Australia  Oceania
# 2     HU-2011-1220       40544     Consumer    Hungary     EMEA
# 3  IT-2011-3647632       40544  Home Office     Sweden    North
# 4    IN-2011-47883       40544     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#   new_sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %%
 data[(data["segment"]== "Corporate") & (data["category"]=="Technology" )]
# Out:
#              order_id  order_date    segment             country  \
# 28     MX-2011-140641       40547  Corporate              Mexico
# 32     MX-2011-140641       40547  Corporate              Mexico
# 55       AO-2011-4910       40549  Corporate              Angola
# 66       LE-2011-9590       40550  Corporate             Lebanon
# 92      ID-2011-20814       40552  Corporate           Indonesia
# ...               ...         ...        ...                 ...
# 51223   IN-2014-78228       42004  Corporate           Indonesia
# 51224  MX-2014-122511       42004  Corporate  Dominican Republic
# 51225    OD-2014-9490       42004  Corporate         South Sudan
# 51232  MX-2014-116267       42004  Corporate              Brazil
# 51248   ID-2014-54442       42004  Corporate         Philippines
#
#                region        product_id    category  \
# 28              North   TEC-AC-10001082  Technology
# 32              North   TEC-CO-10002998  Technology
# ...

# %% [markdown]
# ## Pivot tables

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040       40544     Consumer    Algeria   Africa
# 1    IN-2011-47883       40544     Consumer  Australia  Oceania
# 2     HU-2011-1220       40544     Consumer    Hungary     EMEA
# 3  IT-2011-3647632       40544  Home Office     Sweden    North
# 4    IN-2011-47883       40544     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#   new_sales quantity  discount   profit    year  Unnamed: 14  Unnamed: 15  \
# ...

# %%
data.pivot_table( index="region", columns="category", values="profit", aggfunc={"profit":"sum"})  # index is rows
# Out:
# category         Furniture  Office Supplies    Technology
# region
# Africa          16262.0850       28468.8630   44169.95100
# Canada           2613.2400        7957.5300    7246.62000
# Caribbean        6223.4600       14816.9800   13529.58504
# Central         54543.7601      121223.1495  135564.25064
# Central Asia    48935.7120       27104.5000   56439.97500
# EMEA            11534.1360       14887.0440   17494.44300
# East             3046.1658       40869.1334   47462.03510
# North           30926.6120       64403.3930   99255.21152
# North Asia      52181.3010       40912.2450   72471.01500
# Oceania         33626.4340       33306.1860   54734.02200
# South           22651.6281       67471.0872   50208.13928
# Southeast Asia  -7285.5615        4188.7666   20948.84400
# West            11494.5763       52552.0712   44303.64960

# %% [markdown]
# ## Scatter plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.sales, data["profit"], color="g", s=40,edgecolor="y", label="My Chart")
plt.legend()
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## Concatenate 2 columns

# %%
data.head(2)
# Out:
#         order_id  order_date   segment    country   region        product_id  \
# 0   AG-2011-2040       40544  Consumer    Algeria   Africa  OFF-TEN-10000025
# 1  IN-2011-47883       40544  Consumer  Australia  Oceania   OFF-SU-10000618
#
#           category              product_name sales new_sales quantity  \
# 0  Office Supplies       Tenex Lockers, Blue   408     40800        2
# 1  Office Supplies  Acme Trimmer, High Speed   120     12000        3
#
#    discount   profit    year  Unnamed: 14  Unnamed: 15 new_quantity
# 0       0.0  106.140  2011.0          NaN          NaN           20
# 1       0.1   36.036  2011.0          NaN          NaN           30

# %%
data['concat'] = data['country'] +'(' + data['region'] + ')'

# %%
data.head(2)
# Out:
#         order_id  order_date   segment    country   region        product_id  \
# 0   AG-2011-2040       40544  Consumer    Algeria   Africa  OFF-TEN-10000025
# 1  IN-2011-47883       40544  Consumer  Australia  Oceania   OFF-SU-10000618
#
#           category              product_name sales new_sales quantity  \
# 0  Office Supplies       Tenex Lockers, Blue   408     40800        2
# 1  Office Supplies  Acme Trimmer, High Speed   120     12000        3
#
#    discount   profit    year  Unnamed: 14  Unnamed: 15 new_quantity  \
# 0       0.0  106.140  2011.0          NaN          NaN           20
# 1       0.1   36.036  2011.0          NaN          NaN           30
#
#                concat
# 0     Algeria(Africa)
# 1  Australia(Oceania)
